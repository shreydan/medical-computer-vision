# %%
# !pip install monai accelerate evaluate timm -q

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from pathlib import Path
from tqdm.auto import tqdm
tqdm.pandas()

import monai.transforms as MT
from monai.visualize.utils import matshow3d

from timm import list_models, create_model

from scipy import ndimage as nd

import evaluate
from accelerate import Accelerator, notebook_launcher
from safetensors.torch import load_model

# %env CUDA_LAUNCH_BLOCKING='1'
torch.autograd.set_detect_anomaly(True)
# Out:
# 2024-06-14 16:41:48.111566: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-14 16:41:48.111722: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-14 16:41:48.247858: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# env: CUDA_LAUNCH_BLOCKING='1'

# %%
def create_df(mode='train'):
    sagittal = Path(f'/kaggle/input/mrnet-v1/MRNet-v1.0/{mode}/sagittal')
    axial = Path(f'/kaggle/input/mrnet-v1/MRNet-v1.0/{mode}/axial')
    coronal = Path(f'/kaggle/input/mrnet-v1/MRNet-v1.0/{mode}/coronal')
    axis = [sagittal, axial, coronal]
    labels = ['acl','meniscus','abnormal']
    base_path = Path('/kaggle/input/mrnet-v1/MRNet-v1.0')
    paths = [base_path/f"{mode}-{l}.csv" for l in labels]
    l1 = pd.read_csv(
        paths[0],
        header=None,
        names=['case', labels[0]], 
        dtype={'case': str, labels[0]: np.int64}
    )
    l2 = pd.read_csv(
        paths[1],
        header=None,
        names=['case', labels[1]], 
        dtype={'case': str, labels[1]: np.int64}
    )
    l3 = pd.read_csv(
        paths[2],
        header=None,
        names=['case', labels[2]], 
        dtype={'case': str, labels[2]: np.int64}
    )
    final_df = pd.DataFrame({
        'case': l1['case'],
        labels[0]: l1[labels[0]],
        labels[1]: l2[labels[1]],
        labels[2]: l3[labels[2]],
    })
    for ax in axis:
        final_df[ax.stem] = final_df['case'].progress_map(lambda p: ax / f"{p}.npy")  
    return final_df

# %%
train_df = create_df(mode='train')
valid_df = create_df(mode='valid')
# Out:
#   0%|          | 0/1130 [00:00<?, ?it/s]
#   0%|          | 0/1130 [00:00<?, ?it/s]
#   0%|          | 0/1130 [00:00<?, ?it/s]
#   0%|          | 0/120 [00:00<?, ?it/s]
#   0%|          | 0/120 [00:00<?, ?it/s]
#   0%|          | 0/120 [00:00<?, ?it/s]

# %%
train_df.head()
# Out:
#    case  acl  meniscus  abnormal  \
# 0  0000    0         0         1
# 1  0001    1         1         1
# 2  0002    0         0         1
# 3  0003    0         1         1
# 4  0004    0         0         1
#
#                                             sagittal  \
# 0  /kaggle/input/mrnet-v1/MRNet-v1.0/train/sagitt...
# 1  /kaggle/input/mrnet-v1/MRNet-v1.0/train/sagitt...
# 2  /kaggle/input/mrnet-v1/MRNet-v1.0/train/sagitt...
# 3  /kaggle/input/mrnet-v1/MRNet-v1.0/train/sagitt...
# 4  /kaggle/input/mrnet-v1/MRNet-v1.0/train/sagitt...
#
#                                                axial  \
# 0  /kaggle/input/mrnet-v1/MRNet-v1.0/train/axial/...
# 1  /kaggle/input/mrnet-v1/MRNet-v1.0/train/axial/...
# 2  /kaggle/input/mrnet-v1/MRNet-v1.0/train/axial/...
# 3  /kaggle/input/mrnet-v1/MRNet-v1.0/train/axial/...
# 4  /kaggle/input/mrnet-v1/MRNet-v1.0/train/axial/...
#
#                                              coronal
# 0  /kaggle/input/mrnet-v1/MRNet-v1.0/train/corona...
# 1  /kaggle/input/mrnet-v1/MRNet-v1.0/train/corona...
# 2  /kaggle/input/mrnet-v1/MRNet-v1.0/train/corona...
# 3  /kaggle/input/mrnet-v1/MRNet-v1.0/train/corona...
# 4  /kaggle/input/mrnet-v1/MRNet-v1.0/train/corona...

# %%
for label in ['acl','meniscus','abnormal']:
    print(label)
    print('train',train_df[label].value_counts().to_dict())
    print('valid',valid_df[label].value_counts().to_dict())
# Out:
# acl
# train {0: 922, 1: 208}
# valid {0: 66, 1: 54}
# meniscus
# train {0: 733, 1: 397}
# valid {0: 68, 1: 52}
# abnormal
# train {1: 913, 0: 217}
# valid {1: 95, 0: 25}

# %%
roi = (224,224,-1)
train_tfms = MT.Compose([
    MT.EnsureChannelFirst(channel_dim='no_channel'),
    MT.Transpose((0,2,3,1)),
    MT.HistogramNormalize(),
    MT.ScaleIntensity(),
    MT.Spacing((1.0,1.0,1.0)),
    MT.RandFlip(0.5,0),
    MT.RandFlip(0.5,1),
    MT.RandRotate(np.pi/8,np.pi/8,np.pi/8,0.3),
    MT.RandRotate90(0.2),
    MT.RandZoom(0.2,0.8,1.2),
    MT.Resize(roi),
    MT.RandScaleIntensity(factors=0.1, prob=0.1),
    MT.RandShiftIntensity(offsets=0.1, prob=0.1),
])
valid_tfms = MT.Compose([
    MT.EnsureChannelFirst(channel_dim='no_channel'),
    MT.Transpose((0,2,3,1)),
    MT.HistogramNormalize(),
    MT.ScaleIntensity(),
    MT.Spacing((1.0,1.0,1.0)),
    MT.Resize(roi),
])

# %%
class Dataset:
    def __init__(self, df, tfms, max_len=64, label=None, flat=False):
        self.df = df
        self.max_len = max_len
        self.tfms = tfms
        self.labels = ['acl','meniscus']
        self.label = label
        self.axis = ['sagittal','axial','coronal']
        self.wts = torch.tensor([4.4326, 1.8463, 0.2376])
        self.flat = flat
        
    def __len__(self):
        return len(self.df)
    
    def _apply_tfms(self, im):
        im = self.tfms(im)
        im = im.repeat(3,1,1,1) # 3 channel
        return im
    
    def _prep_im_padding(self, p):
        im = np.load(p)
        pad_len = self.max_len - im.shape[0]
        padding = np.zeros((pad_len, *im.shape[1:]),dtype=im.dtype)
        im = np.vstack([padding, im])
        im = self._apply_tfms(im)
        return im
    
    def _prep_im_interpolate(self, p):
        im = np.load(p)
        dsfactor = [w/float(f) for w,f in zip([64,256,256], im.shape)]
        im_resized = nd.zoom(im, zoom=dsfactor)
        im = self._apply_tfms(im)
        return im
    
    def _open_im(self, p):
        im = np.load(p)
        return im
    
    def _2dify(self, im):
        im = im.permute(3,0,1,2) # c, x, y, z -> z, c, x, y
        return im
        
    def __getitem__(self, idx):
        s = self.df.iloc[idx,:]
        sag, ax, cor = s[self.axis].tolist()
        sag, ax, cor = self._open_im(sag), self._open_im(ax), self._open_im(cor)
        sag, ax, cor = self._apply_tfms(sag), self._apply_tfms(ax), self._apply_tfms(cor)
        if self.flat:
            sag, ax, cor = self._2dify(sag), self._2dify(ax), self._2dify(cor)
        labels = torch.tensor(s[self.labels].tolist()).float()
        return {
            'sagittal': sag,
            'axial': ax,
            'coronal': cor,
            'labels': labels
        }

# %%
train_ds = Dataset(train_df, train_tfms, flat=True)
valid_ds = Dataset(valid_df, valid_tfms, flat=True)

# %%
x = train_ds[10]
print(f"abnormal: {x['labels']}, {x['sagittal'].shape}")
matshow3d(x['sagittal'],frame_dim=0,channel_dim=1)
plt.show()
matshow3d(x['coronal'],frame_dim=0,channel_dim=1)
plt.show()
matshow3d(x['axial'],frame_dim=0,channel_dim=1)
plt.show()
# Out:
# abnormal: tensor([0., 1.]), torch.Size([38, 3, 224, 224])
# /opt/conda/lib/python3.10/site-packages/matplotlib/cm.py:478: RuntimeWarning: invalid value encountered in cast
#   xx = (xx * 255).astype(np.uint8)

# %%
# MAX DEPTH: 

# for ax in ['sagittal','axial','coronal']:
#     lens = []
#     for p in tqdm(train_df[ax]):
#         lens.append(np.load(p).shape[0])
#     print(ax, max(lens), min(lens), sum(lens)/len(lens))
# RESULTS:
# sagittal 51 17 30.41592920353982
# axial 61 19 34.316814159292036
# coronal 58 17 29.77787610619469

# %%
params = lambda m:sum([p.numel() for p in m.parameters() if p.requires_grad])

# %%
class TripleMRNet(nn.Module):
    def __init__(self, num_classes=1):
        super().__init__()
        self.sagittal = create_model('resnet10t',pretrained=True,num_classes=0)
        self.axial = create_model('resnet10t',pretrained=True,num_classes=0)
        self.coronal = create_model('resnet10t',pretrained=True,num_classes=0)
        self.head = nn.Linear(512*3, num_classes)
        
    def backbone(self, trainable=False):
        for m in [self.sagittal, self.axial, self.coronal]:
            for p in m.parameters():
                p.requires_grad = trainable
    
    def forward(self, sagittal, axial, coronal):
        sag = torch.squeeze(sagittal,0)
        ax = torch.squeeze(axial,0)
        cor = torch.squeeze(coronal,0)
        
        sag = self.sagittal(sag)
        ax = self.axial(ax)
        cor = self.coronal(cor)
        
        sag = torch.max(sag, 0, keepdim=True)[0]
        ax = torch.max(ax, 0, keepdim=True)[0]
        cor = torch.max(cor, 0, keepdim=True)[0]
        
        logits = torch.cat([sag, ax, cor], 1)
        logits = self.head(logits)
        return logits

# %%
model = TripleMRNet(num_classes=2)
f"{params(model):,}"
# Out:
# model.safetensors:   0%|          | 0.00/21.8M [00:00<?, ?B/s]
# '14,770,538'

# %%
def train(config):
    
    accelerator = Accelerator()
    
    train_dl = torch.utils.data.DataLoader(
        train_ds,
        batch_size = 1,
        shuffle=True,
        num_workers=4,
        drop_last=True
    )

    valid_dl = torch.utils.data.DataLoader(
        valid_ds,
        batch_size = 1,
        shuffle=False,
        num_workers=4,
    )
    
    pos_wt = torch.tensor([4.4326, 1.8463]).to(accelerator.device)
    loss_fn = nn.BCEWithLogitsLoss(pos_weight=pos_wt)
    valid_loss_fn = nn.BCEWithLogitsLoss() # valid ds is balanced
    
    model = TripleMRNet(num_classes=1)
    load_model(model, '/kaggle/input/triplemrnet-abnormal/TripleMRNet-Abnormal_BEST/model.safetensors')
    model.head = nn.Linear(512*3, 2)
    model.backbone(trainable=False)
    accelerator.print(f"{params(model):,}")
    
    optim = torch.optim.Adam(model.parameters(),lr=config['lr'])
    
    lr_drop = lambda epoch: 1. if epoch < config['freeze_epochs'] else 0.3
    sched = torch.optim.lr_scheduler.LambdaLR(optim,lr_lambda=lr_drop)
    
    model, optim, sched, train_dl, valid_dl = accelerator.prepare(
        model, optim, sched, train_dl, valid_dl
    )
    
    accelerator.print("PRAISE THE LORD! GLORY TO GOD! \n")
    
    best_loss = 1e9
    
    for epoch in range(config['epochs']):
        
        if epoch==config['freeze_epochs']:
            model.backbone(trainable=True)
            accelerator.print(f"\nnow training: {params(model):,} params\n")
        
        model.train()
        
        train_auroc = evaluate.load('roc_auc','multilabel')
        running_loss = 0.
        
        for step, batch in enumerate(train_dl):
            
            inputs = {k:v for k,v in batch.items() if k!='labels'}
            labels = batch['labels']
            preds = model(**inputs)
            loss = loss_fn(preds,labels)
            if step%100==0:
                accelerator.print(f"epoch {epoch}: batch {step}: loss: {loss.item():.4f}")
            accelerator.backward(loss)
            optim.step()
            optim.zero_grad()
            
            running_loss += loss.item()
            preds, labels = accelerator.gather_for_metrics(
                (preds, labels)
            )
            train_auroc.add_batch(references=labels, prediction_scores=preds.sigmoid())
            
        sched.step()
            
        train_loss = running_loss / len(train_dl)
        train_auroc = train_auroc.compute()['roc_auc']
        
        accelerator.print(f"\n{epoch = }")
        accelerator.print(f"{train_loss = :.3f} | {train_auroc = :.3f}\n")
        
        model.eval()
        
        running_loss = 0.
        valid_auroc = evaluate.load('roc_auc','multilabel')
        
        for batch in valid_dl:
            
            inputs = {k:v for k,v in batch.items() if k!='labels'}
            labels = batch['labels']
            with torch.no_grad():
                preds = model(**inputs)
            
            loss = valid_loss_fn(preds, labels)
            running_loss += loss.item()
            
            preds, labels = accelerator.gather_for_metrics(
                (preds, labels)
            )
            valid_auroc.add_batch(references=labels, prediction_scores=preds.sigmoid())
            
            
        valid_loss = running_loss / len(valid_dl)
        valid_auroc = valid_auroc.compute()['roc_auc']
        
        accelerator.print(f"{valid_loss = :.3f} | {valid_auroc = :.3f}")
        
        if valid_loss < best_loss:
            accelerator.print(f'\n\tbest model @ epoch {epoch}\n')
            best_loss = valid_loss
            accelerator.save_model(model, f'./TripleMRNet-Abnormal_BEST')
        
        
        accelerator.save_model(model, f'./TripleMRNet-Abnormal')

# %%
config={
    'lr': 1e-3,
    'epochs': 10,
    'freeze_epochs': 3
}

# %%
notebook_launcher(train,(config,),num_processes=1)
# Out:
# Launching training on one GPU.
# 3,074
# PRAISE THE LORD! GLORY TO GOD!
# Downloading builder script:   0%|          | 0.00/9.54k [00:00<?, ?B/s]
# epoch 0: batch 0: loss: 1.1545
# epoch 0: batch 100: loss: 0.5379
# epoch 0: batch 200: loss: 0.6625
# epoch 0: batch 300: loss: 0.3411
# epoch 0: batch 400: loss: 0.5503
# epoch 0: batch 500: loss: 0.1899
# epoch 0: batch 600: loss: 0.8266
# epoch 0: batch 700: loss: 0.6051
# epoch 0: batch 800: loss: 0.5253
# epoch 0: batch 900: loss: 0.8245
# epoch 0: batch 1000: loss: 0.5201
# epoch 0: batch 1100: loss: 0.2834
#
# epoch = 0
# train_loss = 1.017 | train_auroc = 0.625
#
# valid_loss = 0.691 | valid_auroc = 0.738
#
# 	best model @ epoch 0
#
# epoch 1: batch 0: loss: 0.6489
# epoch 1: batch 100: loss: 1.0091
# epoch 1: batch 200: loss: 0.8425
# epoch 1: batch 300: loss: 1.3516
# epoch 1: batch 400: loss: 0.6980
# epoch 1: batch 500: loss: 0.3515
# epoch 1: batch 600: loss: 0.7137
# epoch 1: batch 700: loss: 0.3926
# epoch 1: batch 800: loss: 0.5018
# epoch 1: batch 900: loss: 0.8219
# epoch 1: batch 1000: loss: 0.3607
# epoch 1: batch 1100: loss: 1.9665
#
# epoch = 1
# train_loss = 0.956 | train_auroc = 0.684
#
# valid_loss = 0.795 | valid_auroc = 0.721
# epoch 2: batch 0: loss: 1.3102
# epoch 2: batch 100: loss: 0.4212
# epoch 2: batch 200: loss: 2.0316
# epoch 2: batch 300: loss: 0.3918
# epoch 2: batch 400: loss: 1.0408
# epoch 2: batch 500: loss: 0.1437
# epoch 2: batch 600: loss: 1.3178
# epoch 2: batch 700: loss: 2.4731
# epoch 2: batch 800: loss: 1.7626
# epoch 2: batch 900: loss: 1.1092
# epoch 2: batch 1000: loss: 0.3488
# epoch 2: batch 1100: loss: 0.7618
#
# epoch = 2
# train_loss = 0.949 | train_auroc = 0.688
#
# valid_loss = 0.734 | valid_auroc = 0.696
#
# now training: 14,770,538 params
#
# epoch 3: batch 0: loss: 1.3412
# epoch 3: batch 100: loss: 0.4785
# epoch 3: batch 200: loss: 0.8084
# epoch 3: batch 300: loss: 1.8020
# epoch 3: batch 400: loss: 0.4526
# epoch 3: batch 500: loss: 0.5073
# epoch 3: batch 600: loss: 0.9383
# epoch 3: batch 700: loss: 0.5180
# epoch 3: batch 800: loss: 0.2674
# epoch 3: batch 900: loss: 0.2552
# epoch 3: batch 1000: loss: 0.7279
# epoch 3: batch 1100: loss: 1.3270
#
# epoch = 3
# train_loss = 0.963 | train_auroc = 0.681
#
# valid_loss = 0.808 | valid_auroc = 0.675
# epoch 4: batch 0: loss: 0.5719
# epoch 4: batch 100: loss: 2.3701
# epoch 4: batch 200: loss: 0.4491
# epoch 4: batch 300: loss: 0.8721
# epoch 4: batch 400: loss: 0.7713
# epoch 4: batch 500: loss: 0.3471
# epoch 4: batch 600: loss: 1.7298
# epoch 4: batch 700: loss: 0.5119
# epoch 4: batch 800: loss: 0.4025
# epoch 4: batch 900: loss: 1.9466
# epoch 4: batch 1000: loss: 0.8431
# epoch 4: batch 1100: loss: 0.1473
#
# epoch = 4
# train_loss = 0.930 | train_auroc = 0.706
#
# valid_loss = 0.854 | valid_auroc = 0.679
# epoch 5: batch 0: loss: 0.0349
# epoch 5: batch 100: loss: 0.1318
# epoch 5: batch 200: loss: 1.5419
# epoch 5: batch 300: loss: 0.3574
# epoch 5: batch 400: loss: 0.6855
# epoch 5: batch 500: loss: 0.9217
# epoch 5: batch 600: loss: 1.7319
# epoch 5: batch 700: loss: 1.2659
# epoch 5: batch 800: loss: 0.7730
# epoch 5: batch 900: loss: 0.6584
# epoch 5: batch 1000: loss: 1.9800
# epoch 5: batch 1100: loss: 0.3535
#
# epoch = 5
# train_loss = 0.899 | train_auroc = 0.731
#
# valid_loss = 0.676 | valid_auroc = 0.693
#
# 	best model @ epoch 5
#
# epoch 6: batch 0: loss: 1.8841
# epoch 6: batch 100: loss: 1.6822
# epoch 6: batch 200: loss: 1.1230
# epoch 6: batch 300: loss: 3.0985
# epoch 6: batch 400: loss: 0.7410
# epoch 6: batch 500: loss: 0.0404
# epoch 6: batch 600: loss: 0.2805
# epoch 6: batch 700: loss: 2.1765
# epoch 6: batch 800: loss: 2.5004
# epoch 6: batch 900: loss: 0.5173
# epoch 6: batch 1000: loss: 5.4733
# epoch 6: batch 1100: loss: 2.2674
#
# epoch = 6
# train_loss = 0.888 | train_auroc = 0.734
#
# valid_loss = 0.624 | valid_auroc = 0.696
#
# 	best model @ epoch 6
#
# epoch 7: batch 0: loss: 0.1968
# epoch 7: batch 100: loss: 0.2788
# epoch 7: batch 200: loss: 1.6222
# epoch 7: batch 300: loss: 0.1440
# epoch 7: batch 400: loss: 0.2986
# epoch 7: batch 500: loss: 0.4583
# epoch 7: batch 600: loss: 0.5620
# epoch 7: batch 700: loss: 0.8083
# epoch 7: batch 800: loss: 1.1836
# epoch 7: batch 900: loss: 0.8313
# epoch 7: batch 1000: loss: 0.0911
# epoch 7: batch 1100: loss: 1.0073
#
# epoch = 7
# train_loss = 0.851 | train_auroc = 0.761
#
# valid_loss = 0.611 | valid_auroc = 0.753
#
# 	best model @ epoch 7
#
# epoch 8: batch 0: loss: 0.1028
# epoch 8: batch 100: loss: 2.5415
# epoch 8: batch 200: loss: 2.0298
# epoch 8: batch 300: loss: 1.1943
# epoch 8: batch 400: loss: 0.5362
# epoch 8: batch 500: loss: 0.9067
# epoch 8: batch 600: loss: 1.1116
# epoch 8: batch 700: loss: 0.5299
# epoch 8: batch 800: loss: 2.1220
# epoch 8: batch 900: loss: 0.2791
# epoch 8: batch 1000: loss: 0.3363
# epoch 8: batch 1100: loss: 0.4033
#
# epoch = 8
# train_loss = 0.856 | train_auroc = 0.760
#
# valid_loss = 0.743 | valid_auroc = 0.766
# epoch 9: batch 0: loss: 1.0596
# epoch 9: batch 100: loss: 0.0833
# epoch 9: batch 200: loss: 0.0945
# epoch 9: batch 300: loss: 1.9055
# epoch 9: batch 400: loss: 2.8600
# epoch 9: batch 500: loss: 0.5055
# epoch 9: batch 600: loss: 1.2828
# epoch 9: batch 700: loss: 0.0563
# epoch 9: batch 800: loss: 0.8714
# epoch 9: batch 900: loss: 2.4671
# epoch 9: batch 1000: loss: 0.2360
# epoch 9: batch 1100: loss: 0.8771
#
# epoch = 9
# train_loss = 0.822 | train_auroc = 0.782
#
# valid_loss = 0.642 | valid_auroc = 0.709
